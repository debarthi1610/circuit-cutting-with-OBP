# %%
from simulated_annealing import perform_simulated_annealing
# Define problem domain
bounds = [(1, 40)]  
n_iterations = 100
step_size = 15
temp = 100

# Perform the simulated annealing search
minimum_index, minimum_value, scores = perform_simulated_annealing(bounds, n_iterations, step_size, temp)

print(f'Best max_qwc group is: {minimum_index}')
print(f'Best Subexperiment is: {minimum_value}')
# Out:
# Reached the specified max_seconds timeout!
# total subexperiments for max_qwc_group 18 is 176
# Value of w for iteration 0 is : 32
# Reached the specified max_seconds timeout!
# total subexperiments for max_qwc_group 32 is 176
# best_eval is : 176
# candidate_eval is : 176
# prob is 1.0
# Value of w for iteration 1 is : 34
# Reached the specified max_seconds timeout!
# total subexperiments for max_qwc_group 34 is 176
# best_eval is : 176
# candidate_eval is : 176
# prob is 1.0
# Value of w for iteration 2 is : 36
# Reached the specified max_seconds timeout!
# total subexperiments for max_qwc_group 36 is 176
# best_eval is : 176
# candidate_eval is : 176
# prob is 1.0
# Value of w for iteration 3 is : 23
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x10366d0d0>>
# Traceback (most recent call last):
# ...

# %%
print(f'The scores list is: {scores}')
# Out:
# The scores list is: [(9, 192), (22, 156), (19, 156)]

# %%
First iteration = [(21, 156), (18, 156)]
Second iteration = [(38,168),(23,156),(21,156),(18,156)]
Third iteration = [(32, 168), (19, 156), (23, 156), (21, 156), (22, 156)]
Fourth iteration = [(20, 156), (22, 156), (23, 156)]
Fifth iteration = [(9, 192), (22, 156), (19, 156)]

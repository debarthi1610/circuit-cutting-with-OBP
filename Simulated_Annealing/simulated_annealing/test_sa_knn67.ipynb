# %%
from simulated_annealing_knn67 import perform_simulated_annealing
# Define problem domain
bounds = [(1, 40)]  
n_iterations = 100
step_size = 15
temp = 100

# Perform the simulated annealing search
minimum_index, minimum_value, scores = perform_simulated_annealing(bounds, n_iterations, step_size, temp)

print(f'Best max_qwc group is: {minimum_index}')
print(f'Best Subexperiment is: {minimum_value}')
# Out:
# total subexperiments for max_qwc_group 37 is 102
# Value of w for iteration 0 is : 26
# total subexperiments for max_qwc_group 26 is 432
# best_eval is : 102
# candidate_eval is : 432
# prob is 0.036883167401240015
# Value of w for iteration 1 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 2 is : 31
# total subexperiments for max_qwc_group 31 is 108
# best_eval is : 102
# candidate_eval is : 108
# prob is 0.835270211411272
# Value of w for iteration 3 is : 29
# total subexperiments for max_qwc_group 29 is 540
# best_eval is : 108
# candidate_eval is : 540
# prob is 3.1288976184971305e-08
# Value of w for iteration 4 is : 22
# total subexperiments for max_qwc_group 22 is 432
# best_eval is : 108
# candidate_eval is : 432
# prob is 9.213600834566135e-08
# Value of w for iteration 5 is : 32
# total subexperiments for max_qwc_group 32 is 102
# best_eval is : 108
# candidate_eval is : 102
# Value of w for iteration 6 is : 26
# best_eval is : 102
# candidate_eval is : 432
# prob is 9.285332670144961e-11
# Value of w for iteration 7 is : 27
# total subexperiments for max_qwc_group 27 is 432
# best_eval is : 102
# candidate_eval is : 432
# prob is 3.4247247924915922e-12
# Value of w for iteration 8 is : 33
# total subexperiments for max_qwc_group 33 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 9 is : 36
# total subexperiments for max_qwc_group 36 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 10 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 11 is : 29
# best_eval is : 102
# candidate_eval is : 540
# prob is 1.4910150637690523e-23
# Value of w for iteration 12 is : 40
# total subexperiments for max_qwc_group 40 is 120
# best_eval is : 102
# candidate_eval is : 120
# prob is 0.09632763823049303
# Value of w for iteration 13 is : 39
# total subexperiments for max_qwc_group 39 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 14 is : 40
# best_eval is : 102
# candidate_eval is : 120
# prob is 0.06720551273974978
# Value of w for iteration 15 is : 30
# total subexperiments for max_qwc_group 30 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 16 is : 38
# total subexperiments for max_qwc_group 38 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 17 is : 31
# best_eval is : 102
# candidate_eval is : 108
# prob is 0.3395955256449391
# Value of w for iteration 18 is : 24
# total subexperiments for max_qwc_group 24 is 432
# best_eval is : 108
# candidate_eval is : 432
# prob is 1.8400587691002675e-27
# Value of w for iteration 19 is : 18
# total subexperiments for max_qwc_group 18 is 396
# best_eval is : 108
# candidate_eval is : 396
# prob is 9.652456261619012e-26
# Value of w for iteration 20 is : 27
# best_eval is : 108
# candidate_eval is : 432
# prob is 2.8223017906305868e-30
# Value of w for iteration 21 is : 21
# total subexperiments for max_qwc_group 21 is 432
# best_eval is : 108
# candidate_eval is : 432
# prob is 1.1053233126594181e-31
# Value of w for iteration 22 is : 18
# best_eval is : 108
# candidate_eval is : 396
# prob is 1.7073930871496397e-29
# Value of w for iteration 23 is : 16
# total subexperiments for max_qwc_group 16 is 396
# best_eval is : 108
# candidate_eval is : 396
# prob is 9.584410601178624e-31
# Value of w for iteration 24 is : 21
# best_eval is : 108
# candidate_eval is : 432
# prob is 6.639677199580735e-36
# Value of w for iteration 25 is : 32
# best_eval is : 108
# candidate_eval is : 102
# Value of w for iteration 26 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 27 is : 25
# total subexperiments for max_qwc_group 25 is 432
# best_eval is : 102
# candidate_eval is : 432
# prob is 7.433440544760343e-41
# Value of w for iteration 28 is : 40
# best_eval is : 102
# candidate_eval is : 120
# prob is 0.005407329126440955
# Value of w for iteration 29 is : 28
# total subexperiments for max_qwc_group 28 is 540
# best_eval is : 102
# candidate_eval is : 540
# prob is 8.58430377876758e-58
# Value of w for iteration 30 is : 24
# best_eval is : 102
# candidate_eval is : 432
# prob is 3.729705159168253e-45
# Value of w for iteration 31 is : 39
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 32 is : 31
# best_eval is : 102
# candidate_eval is : 108
# prob is 0.13806923731089282
# Value of w for iteration 33 is : 25
# best_eval is : 102
# candidate_eval is : 432
# prob is 1.8713677052454805e-49
# Value of w for iteration 34 is : 32
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 35 is : 32
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 36 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 37 is : 24
# best_eval is : 102
# candidate_eval is : 432
# prob is 3.463155316443381e-55
# Value of w for iteration 38 is : 39
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 39 is : 29
# best_eval is : 102
# candidate_eval is : 540
# prob is 8.158433361583297e-77
# Value of w for iteration 40 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 41 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 42 is : 35
# total subexperiments for max_qwc_group 35 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 43 is : 39
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 44 is : 26
# best_eval is : 102
# candidate_eval is : 432
# prob is 3.21565492015576e-65
# Value of w for iteration 45 is : 35
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 46 is : 22
# best_eval is : 102
# candidate_eval is : 432
# prob is 4.3744741731635435e-68
# Value of w for iteration 47 is : 26
# best_eval is : 102
# candidate_eval is : 432
# prob is 1.613444632211947e-69
# Value of w for iteration 48 is : 36
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 49 is : 34
# total subexperiments for max_qwc_group 34 is 102
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 50 is : 28
# best_eval is : 102
# candidate_eval is : 540
# prob is 9.711775452408663e-98
# Value of w for iteration 51 is : 28
# best_eval is : 102
# candidate_eval is : 540
# prob is 1.2164347038876598e-99
# Value of w for iteration 52 is : 40
# best_eval is : 102
# candidate_eval is : 120
# prob is 7.191684765732902e-05
# Value of w for iteration 53 is : 40
# best_eval is : 102
# candidate_eval is : 120
# prob is 6.007000054676936e-05
# Value of w for iteration 54 is : 25
# best_eval is : 102
# candidate_eval is : 432
# prob is 1.4981370154947242e-79
# Value of w for iteration 55 is : 25
# best_eval is : 102
# candidate_eval is : 432
# prob is 5.525603833248695e-81
# Value of w for iteration 56 is : 36
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 57 is : 39
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 58 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 59 is : 30
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 60 is : 26
# best_eval is : 102
# candidate_eval is : 432
# prob is 3.771558018051119e-88
# Value of w for iteration 61 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 62 is : 40
# best_eval is : 102
# candidate_eval is : 120
# prob is 1.1887774962157688e-05
# Value of w for iteration 63 is : 34
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 64 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 65 is : 33
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 66 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 67 is : 29
# best_eval is : 102
# candidate_eval is : 540
# prob is 4.4640752821867866e-130
# Value of w for iteration 68 is : 34
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 69 is : 27
# best_eval is : 102
# candidate_eval is : 432
# prob is 4.764032113782328e-101
# Value of w for iteration 70 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 71 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 72 is : 22
# best_eval is : 102
# candidate_eval is : 432
# prob is 2.390337966144357e-105
# Value of w for iteration 73 is : 26
# best_eval is : 102
# candidate_eval is : 432
# prob is 8.816323535084088e-107
# Value of w for iteration 74 is : 33
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 75 is : 29
# best_eval is : 102
# candidate_eval is : 540
# prob is 2.704287520669968e-145
# Value of w for iteration 76 is : 28
# best_eval is : 102
# candidate_eval is : 540
# prob is 3.387217101088761e-147
# Value of w for iteration 77 is : 35
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 78 is : 28
# best_eval is : 102
# candidate_eval is : 540
# prob is 5.314022291018901e-151
# Value of w for iteration 79 is : 22
# best_eval is : 102
# candidate_eval is : 432
# prob is 2.219508320972814e-115
# Value of w for iteration 80 is : 25
# best_eval is : 102
# candidate_eval is : 432
# prob is 8.186249695088449e-117
# Value of w for iteration 81 is : 36
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 82 is : 36
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 83 is : 30
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 84 is : 35
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 85 is : 30
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 86 is : 28
# best_eval is : 102
# candidate_eval is : 540
# prob is 3.219176034846078e-166
# Value of w for iteration 87 is : 32
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 88 is : 38
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 89 is : 23
# total subexperiments for max_qwc_group 23 is 432
# best_eval is : 102
# candidate_eval is : 432
# prob is 1.0340436565521947e-129
# Value of w for iteration 90 is : 39
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 91 is : 25
# best_eval is : 102
# candidate_eval is : 432
# prob is 1.4066799398027249e-132
# Value of w for iteration 92 is : 25
# best_eval is : 102
# candidate_eval is : 432
# prob is 5.188281169970953e-134
# Value of w for iteration 93 is : 35
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 94 is : 31
# best_eval is : 102
# candidate_eval is : 108
# prob is 0.003345965457471272
# Value of w for iteration 95 is : 21
# best_eval is : 102
# candidate_eval is : 432
# prob is 2.603203581213545e-138
# Value of w for iteration 96 is : 40
# best_eval is : 102
# candidate_eval is : 120
# prob is 2.6134749752863247e-08
# Value of w for iteration 97 is : 37
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 98 is : 32
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Value of w for iteration 99 is : 35
# best_eval is : 102
# candidate_eval is : 102
# prob is 1.0
# Best max_qwc group is: 35
# Best Subexperiment is: 102

# %%
print(f'The scores list is: {scores}')
# Out:
# The scores list is: [(37, 102), (32, 102), (32, 102)]

# %%
First iteration = [(21, 176)]
Second iteration = 
Third iteration = 
Fourth iteration = 
Fifth iteration =
